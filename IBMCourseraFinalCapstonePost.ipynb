# %% [markdown]
# ## Introduction/BusinessmProblem: In this project we have an assignment to determine the best neighborhoods to open up a bake shop within New York or Toronto. The given in this case are the most competitive prices of production costs (to compete with other bakeshops) and the most talented sales team (to push our products to the coffee shops). In this notebook, using KNN clusters and a map, we will find neighborhoods with the highest concentration of coffee shops (potential clients) and find a location that will be the closest for distrubition of the goods. I will begin with Toronto first:

# %%
#Import Packages
import numpy as np
import pandas as pd
import json
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
#!conda install -c conda-forge folium=0.5.0
import folium

# %%
#Obtain and clean location data
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M') # download data
df = df[0]# Select appropriate index for data
df = df[df['Borough']!='Not assigned'] # Remove all boroughs that don't have an assigned zip code
df['Borough'].unique() # checking no other data anomilies exist
df = df.groupby(['Postcode','Borough'], as_index = False, sort = False).agg(','.join) # Comebine neighborhoods within the same zip code and Borough
df['Neighbourhood'] = np.where(df["Neighbourhood"] == 'Not assigned', df['Borough'], df['Neighbourhood']) # Missing values in Neighborhood replaced with Borough.
df.shape
#Add longitude and latitude
df2 = pd.read_csv('http://cocl.us/Geospatial_data')
df = pd.merge(df,df2,how = 'left', left_on=df['Postcode'], right_on=df2['Postal Code'])
df = df[['Postcode','Borough', 'Neighbourhood', 'Latitude','Longitude']]
df.head(5)
#Create a map of toronto
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="Toronto_Location")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
#Select the most concentrated are in Toronto (Downtown Toronto)

df_toronto = df[df['Borough'] == 'Downtown Toronto']
address = 'Downtown Toronto, Toronto'

geolocator = Nominatim(user_agent="Toronto")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronro are {}, {}.'.format(latitude, longitude))

#Create a map of the neighborhooods in downtown Toronto
# create map of Toronto using latitude and longitude values
Dtown_Toronto_map = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Dtown_Toronto_map)  
    
Dtown_Toronto_map
# Out:
# The geograpical coordinate of Downtown Toronro are 43.6541737, -79.3808116451341.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#FOursquare credentials
CLIENT_ID = 'X' # your Foursquare ID
CLIENT_SECRET = 'X' # your Foursquare Secret
VERSION = 'X' # Foursquare API version

# %%
#Obtain top 20 Venues within 500 meters
LIMIT = 20 #limit for venues defined
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)
toronto_venues = getNearbyVenues(names=df_toronto['Neighbourhood'],
                                   latitudes=df_toronto['Latitude'],
                                   longitudes=df_toronto['Longitude']
                                  )
#One hot encoding of the obtained data
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped.head(3)

#Most common 20 venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 20

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()

#Cluster Neighborhoods N=4
# set number of clusters
kclusters = 4

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)


# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df_toronto

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

toronto_merged = toronto_merged.dropna() # drop any neighborhoods that didnt have any data

toronto_merged.head()
# Out:
# Harbourfront,Regent Park
# Ryerson,Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Christie
# Adelaide,King,Richmond
# Harbourfront East,Toronto Islands,Union Station
# Design Exchange,Toronto Dominion Centre
# Commerce Court,Victoria Hotel
# Harbord,University of Toronto
# Chinatown,Grange Park,Kensington Market
# CN Tower,Bathurst Quay,Island airport,Harbourfront West,King and Spadina,Railway Lands,South Niagara
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# Cabbagetown,St. James Town
# First Canadian Place,Underground city
# Church and Wellesley
#    Postcode           Borough             Neighbourhood   Latitude  Longitude  \
# 2       M5A  Downtown Toronto  Harbourfront,Regent Park  43.654260 -79.360636
# 9       M5B  Downtown Toronto   Ryerson,Garden District  43.657162 -79.378937
# 15      M5C  Downtown Toronto            St. James Town  43.651494 -79.375418
# 20      M5E  Downtown Toronto               Berczy Park  43.644771 -79.373306
# 24      M5G  Downtown Toronto        Central Bay Street  43.657952 -79.387383
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2                2           Coffee Shop        Breakfast Spot
# 9                1                  Café        Clothing Store
# 15               0             Gastropub           Coffee Shop
# 20               1        Farmers Market              Beer Bar
# 24               2           Coffee Shop       Bubble Tea Shop
#
#    3rd Most Common Venue 4th Most Common Venue  ... 11th Most Common Venue  \
# 2   Gym / Fitness Center                Bakery  ...          Historic Site
# 9             Comic Shop        Sandwich Place  ...       Ramen Restaurant
# 15            Restaurant   Japanese Restaurant  ...                  Hotel
# 20                  Park    Basketball Stadium  ...           Cocktail Bar
# 24                   Spa                  Park  ...     Italian Restaurant
#
#    12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 2   Performing Arts Venue         Chocolate Shop           Concert Hall
# 9                Beer Bar            Music Venue                Theater
# 15    American Restaurant             Food Truck                   Café
# 20            Fish Market               Tea Room        Thai Restaurant
# 24     Seafood Restaurant               Tea Room          Deli / Bodega
#
#      15th Most Common Venue 16th Most Common Venue  \
# 2               College Gym           Cocktail Bar
# 9                     Diner        Thai Restaurant
# 15                      Gym      Convenience Store
# 20                   Museum      French Restaurant
# 24  Comfort Food Restaurant         Chocolate Shop
#
#            17th Most Common Venue   18th Most Common Venue  \
# 2                  Clothing Store  Comfort Food Restaurant
# 9                      Taco Place                 Tea Room
# 15                     Comic Shop              College Gym
# 20  Vegetarian / Vegan Restaurant                   Bistro
# 24                         Church        French Restaurant
#
#    19th Most Common Venue 20th Most Common Venue
# 2                  Church             Comic Shop
# 9           Deli / Bodega           Cocktail Bar
# 15           Concert Hall           Cocktail Bar
# 20         Clothing Store            College Gym
# 24               Fountain         Clothing Store
#
# [5 rows x 26 columns]

# %%
#Create a cluster map
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)],
        fill=True,
        fill_color=rainbow[int(cluster)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Examination of CLusters #1
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                               Neighbourhood  Cluster Labels  \
# 15                           St. James Town               0
# 25                                 Christie               0
# 42  Design Exchange,Toronto Dominion Centre               0
# 48            Commerce Court,Victoria Hotel               0
# 84  Chinatown,Grange Park,Kensington Market               0
# 97    First Canadian Place,Underground city               0
#
#    1st Most Common Venue  2nd Most Common Venue 3rd Most Common Venue  \
# 15             Gastropub            Coffee Shop            Restaurant
# 25         Grocery Store                   Café                  Park
# 42           Coffee Shop                   Café            Restaurant
# 48                  Café              Gastropub           Coffee Shop
# 84                  Café  Vietnamese Restaurant    Mexican Restaurant
# 97                  Café            Coffee Shop            Restaurant
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 15   Japanese Restaurant             BBQ Joint              Creperie
# 25    Italian Restaurant    Athletics & Sports            Restaurant
# 42         Deli / Bodega             Gastropub                 Hotel
# 48            Restaurant                Bakery                Museum
# 84              Wine Bar                Bakery        Farmers Market
# 97            Steakhouse           Pizza Place    Seafood Restaurant
#
#         7th Most Common Venue 8th Most Common Venue  ...  \
# 15  Middle Eastern Restaurant                Church  ...
# 25                Coffee Shop                 Diner  ...
# 42                        Pub   Japanese Restaurant  ...
# 48                        Pub         Deli / Bodega  ...
# 84               Dessert Shop           Coffee Shop  ...
# 97                        Pub                   Bar  ...
#
#    11th Most Common Venue 12th Most Common Venue 13th Most Common Venue  \
# 15                  Hotel    American Restaurant             Food Truck
# 25              Nightclub           Cocktail Bar           Concert Hall
# 42    Fried Chicken Joint    American Restaurant                    Gym
# 48                    Gym    American Restaurant   Gym / Fitness Center
# 84   Caribbean Restaurant                    Bar            Cheese Shop
# 97             Food Court    American Restaurant   Gym / Fitness Center
#
#    14th Most Common Venue         15th Most Common Venue  \
# 15                   Café                            Gym
# 25         Clothing Store                      Gastropub
# 42   Gym / Fitness Center                     Food Court
# 48            Fish Market                   Concert Hall
# 84           Gourmet Shop  Vegetarian / Vegan Restaurant
# 97                    Gym              Convenience Store
#
#      16th Most Common Venue 17th Most Common Venue   18th Most Common Venue  \
# 15        Convenience Store             Comic Shop              College Gym
# 25                   Church            College Gym  Comfort Food Restaurant
# 42        Convenience Store           Cocktail Bar        French Restaurant
# 48             Cocktail Bar    Fried Chicken Joint        French Restaurant
# 84      Arts & Crafts Store           Airport Gate               Comic Shop
# 97  Comfort Food Restaurant             Comic Shop             Cocktail Bar
#
#    19th Most Common Venue   20th Most Common Venue
# 15           Concert Hall             Cocktail Bar
# 25             Comic Shop      Fried Chicken Joint
# 42            College Gym  Comfort Food Restaurant
# 48            College Gym  Comfort Food Restaurant
# 84           Concert Hall           Airport Lounge
# 97         Clothing Store             Concert Hall
#
# [6 rows x 22 columns]

# %%
#Examination of CLusters #2
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                         Neighbourhood  Cluster Labels  \
# 9                             Ryerson,Garden District               1
# 20                                        Berczy Park               1
# 30                             Adelaide,King,Richmond               1
# 36    Harbourfront East,Toronto Islands,Union Station               1
# 80                      Harbord,University of Toronto               1
# 87  CN Tower,Bathurst Quay,Island airport,Harbourf...               1
# 92                    Stn A PO Boxes 25 The Esplanade               1
# 96                         Cabbagetown,St. James Town               1
# 99                               Church and Wellesley               1
#
#    1st Most Common Venue 2nd Most Common Venue  3rd Most Common Venue  \
# 9                   Café        Clothing Store             Comic Shop
# 20        Farmers Market              Beer Bar                   Park
# 30            Steakhouse                 Plaza            Coffee Shop
# 36                  Café                  Park     Italian Restaurant
# 80             Bookstore            Restaurant                 Bakery
# 87       Airport Service        Airport Lounge       Airport Terminal
# 92                  Café        Farmers Market           Cocktail Bar
# 96                  Café            Restaurant  General Entertainment
# 99          Burger Joint                   Pub             Restaurant
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 9         Sandwich Place         Movie Theater         Burrito Place
# 20    Basketball Stadium    Seafood Restaurant        Breakfast Spot
# 30    Seafood Restaurant                   Bar                 Hotel
# 36                 Hotel           Salad Place                 Plaza
# 80   Japanese Restaurant        Sandwich Place              Beer Bar
# 87               Airport       Harbor / Marina      Sculpture Garden
# 92                Museum        Clothing Store          Concert Hall
# 96             Gift Shop                 Diner         Deli / Bodega
# 99             Bookstore    Salon / Barbershop             Juice Bar
#
#    7th Most Common Venue 8th Most Common Venue  ...   11th Most Common Venue  \
# 9           Burger Joint           Pizza Place  ...         Ramen Restaurant
# 20          Liquor Store            Steakhouse  ...             Cocktail Bar
# 30             Speakeasy           Pizza Place  ...              Opera House
# 36                Bistro       Bubble Tea Shop  ...           Ice Cream Shop
# 80                   Bar    Italian Restaurant  ...  Comfort Food Restaurant
# 87         Boat or Ferry                   Bar  ...             Airport Gate
# 92              Beer Bar             Jazz Club  ...               Food Truck
# 96     Indian Restaurant    Italian Restaurant  ...     Caribbean Restaurant
# 99        Breakfast Spot   Japanese Restaurant  ...                 Creperie
#
#            12th Most Common Venue 13th Most Common Venue  \
# 9                        Beer Bar            Music Venue
# 20                    Fish Market               Tea Room
# 30            American Restaurant                   Café
# 36                         Bakery    Sporting Goods Shop
# 80                    College Gym                   Café
# 87             Airport Food Court            College Gym
# 92  Vegetarian / Vegan Restaurant      French Restaurant
# 96                           Park                Butcher
# 99                   Dance Studio                   Park
#
#      14th Most Common Venue 15th Most Common Venue 16th Most Common Venue  \
# 9                   Theater                  Diner        Thai Restaurant
# 20          Thai Restaurant                 Museum      French Restaurant
# 30         Greek Restaurant           Concert Hall             Food Court
# 36              Supermarket  Performing Arts Venue          Deli / Bodega
# 80                  Theater      French Restaurant       Sushi Restaurant
# 87  Comfort Food Restaurant           Dessert Shop           Concert Hall
# 92                 Fountain               Tea Room        Thai Restaurant
# 96                Pet Store                    Pub              Gastropub
# 99                    Diner     Mexican Restaurant               Tea Room
#
#            17th Most Common Venue         18th Most Common Venue  \
# 9                      Taco Place                       Tea Room
# 20  Vegetarian / Vegan Restaurant                         Bistro
# 30                   Neighborhood  Vegetarian / Vegan Restaurant
# 36        New American Restaurant                   Neighborhood
# 80                     Comic Shop                    Coffee Shop
# 87              Convenience Store                 Cosmetics Shop
# 92                    Tailor Shop        Comfort Food Restaurant
# 96           Taiwanese Restaurant                         Bakery
# 99               Theme Restaurant          General Entertainment
#
#      19th Most Common Venue 20th Most Common Venue
# 9             Deli / Bodega           Cocktail Bar
# 20           Clothing Store            College Gym
# 30                   Lounge            College Gym
# 36  Comfort Food Restaurant            Coffee Shop
# 80             Cocktail Bar           Concert Hall
# 87                 Creperie           Dance Studio
# 92       Chinese Restaurant         Chocolate Shop
# 96       Basketball Stadium           Dance Studio
# 99                Gastropub       Ramen Restaurant
#
# [9 rows x 22 columns]

# %%
#Examination of CLusters #3
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                Neighbourhood  Cluster Labels 1st Most Common Venue  \
# 2   Harbourfront,Regent Park               2           Coffee Shop
# 24        Central Bay Street               2           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 2         Breakfast Spot  Gym / Fitness Center                Bakery
# 24       Bubble Tea Shop                   Spa                  Park
#
#    5th Most Common Venue       6th Most Common Venue 7th Most Common Venue  \
# 2                   Park                  Restaurant                   Spa
# 24      Sushi Restaurant  Modern European Restaurant             Gastropub
#
#    8th Most Common Venue  ... 11th Most Common Venue 12th Most Common Venue  \
# 2                    Pub  ...          Historic Site  Performing Arts Venue
# 24      Ramen Restaurant  ...     Italian Restaurant     Seafood Restaurant
#
#    13th Most Common Venue 14th Most Common Venue   15th Most Common Venue  \
# 2          Chocolate Shop           Concert Hall              College Gym
# 24               Tea Room          Deli / Bodega  Comfort Food Restaurant
#
#    16th Most Common Venue 17th Most Common Venue   18th Most Common Venue  \
# 2            Cocktail Bar         Clothing Store  Comfort Food Restaurant
# 24         Chocolate Shop                 Church        French Restaurant
#
#    19th Most Common Venue 20th Most Common Venue
# 2                  Church             Comic Shop
# 24               Fountain         Clothing Store
#
# [2 rows x 22 columns]

# %%
#Examination of CLusters #4
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    Neighbourhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 91      Rosedale               3                  Park                 Trail
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 91            Playground              Building        Cosmetics Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  ...  \
# 91    Chinese Restaurant        Chocolate Shop                Church  ...
#
#    11th Most Common Venue 12th Most Common Venue   13th Most Common Venue  \
# 91            Coffee Shop            College Gym  Comfort Food Restaurant
#
#    14th Most Common Venue 15th Most Common Venue 16th Most Common Venue  \
# 91             Comic Shop           Concert Hall      Convenience Store
#
#    17th Most Common Venue 18th Most Common Venue 19th Most Common Venue  \
# 91               Wine Bar            Cheese Shop           Dance Studio
#
#    20th Most Common Venue
# 91          Deli / Bodega
#
# [1 rows x 22 columns]

# %% [markdown]
# # After reviewiwng map and data, I would suggest to explore cluster 1 and cluster 3 for further exploration. These areas have coffee shops and cafes as the most visited venues in the areas. From there, strategical points can be selected which are the most convenient for deliveries of goods.

# %% [markdown]
# # New York location exploration

# %%
#Obtain and clean location data
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)
    neighborhoods_data = newyork_data['features']
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %%
#Create map of NY data
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Staten Island area looks like a good concentrated area, we will select this area.

# %%
si_data = neighborhoods[neighborhoods['Borough'] == 'Staten Island'].reset_index(drop=True)
si_data.head()


#latitude = 40.571944
#longitude = -74.146944
#si_data = neighborhood[neighborhood['Borough'] == 'Staten Island']
address = 'Staten Island, New York'

geolocator = Nominatim(user_agent="NewYork")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print('The geograpical coordinate of Staten Island are {}, {}.'.format(latitude, longitude))

#Create a map of Staten Island

# create map of Manhattan using latitude and longitude values
map_si = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, label in zip(si_data['Latitude'], si_data['Longitude'], si_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_si)  
    
map_si
# Out:
# The geograpical coordinate of Staten Island are 40.5834557, -74.1496048.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Obtain top 20 Venues within 500 meters

LIMIT = 20 #limit for venues defined
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)
si_venues = getNearbyVenues(names=si_data['Neighborhood'],
                                   latitudes=si_data['Latitude'],
                                   longitudes=si_data['Longitude']
                                  )
#One hot encoding of the obtained data
# one hot encoding
si_onehot = pd.get_dummies(si_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
si_onehot['Neighborhood'] = si_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [si_onehot.columns[-1]] + list(si_onehot.columns[:-1])
si_onehot = si_onehot[fixed_columns]

si_grouped = si_onehot.groupby('Neighborhood').mean().reset_index()
si_grouped.head(3)

#Most common 20 venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 20

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = si_grouped['Neighborhood']

for ind in np.arange(si_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(si_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()

#Cluster Neighborhoods N=4
# set number of clusters
kclusters = 4

si_grouped_clustering = si_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(si_grouped_clustering)


# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

si_merged = si_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
si_merged = si_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

si_merged = si_merged.dropna() # drop any neighborhoods that didnt have any data

si_merged.head()
# Out:
# St. George
# New Brighton
# Stapleton
# Rosebank
# West Brighton
# Grymes Hill
# Todt Hill
# South Beach
# Port Richmond
# Mariner's Harbor
# Port Ivory
# Castleton Corners
# New Springville
# Travis
# New Dorp
# Oakwood
# Great Kills
# Eltingville
# Annadale
# Woodrow
# Tottenville
# Tompkinsville
# Silver Lake
# Sunnyside
# Park Hill
# Westerleigh
# Graniteville
# Arlington
# Arrochar
# Grasmere
# Old Town
# Dongan Hills
# Midland Beach
# Grant City
# New Dorp Beach
# Bay Terrace
# Huguenot
# Pleasant Plains
# Butler Manor
# Charleston
# Rossville
# Arden Heights
# Greenridge
# Heartland Village
# Chelsea
# Bloomfield
# Bulls Head
# Richmond Town
# Shore Acres
# Clifton
# Concord
# Emerson Hill
# Randall Manor
# Howland Hook
# Elm Park
# Manor Heights
# Willowbrook
# Sandy Ground
# Egbertville
# Prince's Bay
# Lighthouse Hill
# Richmond Valley
# Fox Hills
#          Borough   Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0  Staten Island     St. George  40.644982 -74.079353             0.0
# 1  Staten Island   New Brighton  40.640615 -74.087017             1.0
# 2  Staten Island      Stapleton  40.626928 -74.077902             0.0
# 3  Staten Island       Rosebank  40.615305 -74.069805             0.0
# 4  Staten Island  West Brighton  40.631879 -74.107182             0.0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0        Clothing Store    Italian Restaurant                   Bar
# 1              Bus Stop                  Park         Deli / Bodega
# 2        Discount Store        Sandwich Place    Mexican Restaurant
# 3    Italian Restaurant           Pizza Place         Grocery Store
# 4           Coffee Shop    Italian Restaurant           Music Store
#
#    4th Most Common Venue 5th Most Common Venue  ... 11th Most Common Venue  \
# 0       Tapas Restaurant           Art Gallery  ...            Pizza Place
# 1          Bowling Alley        Discount Store  ...            Flower Shop
# 2  Sri Lankan Restaurant              Beer Bar  ...             Skate Park
# 3             Bagel Shop    Mexican Restaurant  ...         Breakfast Spot
# 4             Taco Place            Bagel Shop  ...      German Restaurant
#
#   12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 0                  Plaza             Steakhouse    American Restaurant
# 1    Filipino Restaurant   Fast Food Restaurant            Event Space
# 2   Fast Food Restaurant     Spanish Restaurant            Pizza Place
# 3             Restaurant         Cosmetics Shop         Ice Cream Shop
# 4         Ice Cream Shop              Juice Bar     Mexican Restaurant
#
#   15th Most Common Venue 16th Most Common Venue 17th Most Common Venue  \
# 0       Toy / Game Store                Theater     Tex-Mex Restaurant
# 1     Falafel Restaurant     Dim Sum Restaurant      Electronics Store
# 2       Asian Restaurant                   Bank                    Bar
# 3            Video Store         Discount Store    Filipino Restaurant
# 4    American Restaurant            Wings Joint             Donut Shop
#
#         18th Most Common Venue 19th Most Common Venue 20th Most Common Venue
# 0                      Dog Run   Fast Food Restaurant     Falafel Restaurant
# 1  Eastern European Restaurant            Dry Cleaner             Donut Shop
# 2                 Gourmet Shop         Hardware Store      Electronics Store
# 3         Fast Food Restaurant            Flower Shop            Dry Cleaner
# 4          Filipino Restaurant   Fast Food Restaurant     Falafel Restaurant
#
# [5 rows x 25 columns]

# %%
#Create a cluster map
# create map
map_si = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(si_merged['Latitude'], si_merged['Longitude'], si_merged['Neighborhood'], si_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)],
        fill=True,
        fill_color=rainbow[int(cluster)],
        fill_opacity=0.7).add_to(map_si)
       
map_si
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Examination of CLusters #1
si_merged.loc[si_merged['Cluster Labels'] == 0, si_merged.columns[[1] + list(range(5, si_merged.shape[1]))]]
# Out:
#          Neighborhood       1st Most Common Venue    2nd Most Common Venue  \
# 0          St. George              Clothing Store       Italian Restaurant
# 2           Stapleton              Discount Store           Sandwich Place
# 3            Rosebank          Italian Restaurant              Pizza Place
# 4       West Brighton                 Coffee Shop       Italian Restaurant
# 7         South Beach               Deli / Bodega                     Pier
# 9    Mariner's Harbor          Italian Restaurant            Deli / Bodega
# 11  Castleton Corners                 Pizza Place                     Bank
# 12    New Springville     Health & Beauty Service               Bagel Shop
# 13             Travis                       Hotel            Bowling Alley
# 14           New Dorp          Italian Restaurant              Pizza Place
# 16        Great Kills          Italian Restaurant              Pizza Place
# 17        Eltingville                 Pizza Place         Sushi Restaurant
# 18           Annadale                 Pizza Place               Sports Bar
# 19            Woodrow                    Pharmacy       Italian Restaurant
# 20        Tottenville          Italian Restaurant   Thrift / Vintage Store
# 21      Tompkinsville                 Pizza Place         Recording Studio
# 25        Westerleigh                      Arcade       Spanish Restaurant
# 26       Graniteville                 Supermarket            Boat or Ferry
# 28           Arrochar                    Bus Stop       Italian Restaurant
# 30           Old Town          Italian Restaurant                      Spa
# 31       Dongan Hills          Italian Restaurant                     Bank
# 33         Grant City          Miscellaneous Shop  Health & Beauty Service
# 34     New Dorp Beach          Italian Restaurant                     Food
# 35        Bay Terrace                 Supermarket               Donut Shop
# 36           Huguenot          Italian Restaurant         Asian Restaurant
# 37    Pleasant Plains                  Donut Shop              Pizza Place
# 39         Charleston              Cosmetics Shop            Big Box Store
# 40          Rossville                 Pizza Place               Bagel Shop
# 43  Heartland Village               Moving Target                 Pharmacy
# 44            Chelsea          Italian Restaurant           Sandwich Place
# 46         Bulls Head               Deli / Bodega                 Pharmacy
# 47      Richmond Town          Italian Restaurant               Bagel Shop
# 48        Shore Acres          Italian Restaurant                      Bar
# 49            Clifton               Grocery Store              Pizza Place
# 50            Concord        Gym / Fitness Center      Peruvian Restaurant
# 51       Emerson Hill  Construction & Landscaping         Sculpture Garden
# 54           Elm Park          Italian Restaurant              Pizza Place
# 55      Manor Heights               Deli / Bodega             Liquor Store
# 57       Sandy Ground                Intersection     Fast Food Restaurant
# 58        Egbertville          Italian Restaurant           Clothing Store
# 59       Prince's Bay                 Pizza Place       Italian Restaurant
# 60    Lighthouse Hill          Italian Restaurant                     Café
# 61    Richmond Valley        Fast Food Restaurant            Deli / Bodega
#
#       3rd Most Common Venue   4th Most Common Venue  \
# 0                       Bar        Tapas Restaurant
# 2        Mexican Restaurant   Sri Lankan Restaurant
# 3             Grocery Store              Bagel Shop
# 4               Music Store              Taco Place
# 7        Athletics & Sports                   Beach
# 9            Ice Cream Shop                Bus Stop
# 11            Deli / Bodega     Japanese Restaurant
# 12           Ice Cream Shop            Liquor Store
# 13            Deli / Bodega             Comedy Club
# 14                     Bank              Hobby Shop
# 16                      Bar            Liquor Store
# 17                     Bank      Italian Restaurant
# 18                     Park           Deli / Bodega
# 19        Martial Arts Dojo                   Diner
# 20             Home Service      Mexican Restaurant
# 21      Rental Car Location    Caribbean Restaurant
# 25        Convenience Store             Comedy Club
# 26               Food Truck          Sandwich Place
# 28              Pizza Place           Deli / Bodega
# 30                   Bakery                    Bank
# 31            Deli / Bodega             Pizza Place
# 33        French Restaurant  Furniture / Home Store
# 34            Deli / Bodega                   Diner
# 35         Insurance Office              Playground
# 36  Comfort Food Restaurant          Sandwich Place
# 37              Yoga Studio                    Bank
# 39               Kids Store               Gift Shop
# 40           Ice Cream Shop      Chinese Restaurant
# 43                Bookstore       Electronics Store
# 44                      Bar              Steakhouse
# 46               Hookah Bar              Donut Shop
# 47                     Café                     Spa
# 48                 Bus Stop           Deli / Bodega
# 49            Train Station           Deli / Bodega
# 50            Deli / Bodega             Supermarket
# 51            Historic Site             Yoga Studio
# 54                   Bakery                Bus Stop
# 55               Donut Shop              Campground
# 57              Art Gallery                Bus Stop
# 58             Dance Studio          Cosmetics Shop
# 59         Sushi Restaurant                Pharmacy
# 60               Art Museum                     Spa
# 61            Train Station                    Food
#
#           5th Most Common Venue      6th Most Common Venue  \
# 0                   Art Gallery           Baseball Stadium
# 2                      Beer Bar                       Park
# 3            Mexican Restaurant  Cajun / Creole Restaurant
# 4                    Bagel Shop                        Bar
# 7                   Yoga Studio       Fast Food Restaurant
# 9                Nightlife Spot         Athletics & Sports
# 11               Hardware Store              Grocery Store
# 12            Mobile Phone Shop              Shopping Mall
# 13           Spanish Restaurant                       Park
# 14           Mexican Restaurant         Dim Sum Restaurant
# 16               Cosmetics Shop                   Pharmacy
# 17                          Bar              Deli / Bodega
# 18                 Dance Studio                      Diner
# 19                  Pizza Place               Dessert Shop
# 20               Cosmetics Shop                   Bus Stop
# 21                      Brewery      Sri Lankan Restaurant
# 25                  Yoga Studio         Falafel Restaurant
# 26           Falafel Restaurant          French Restaurant
# 28                        Hotel             Cosmetics Shop
# 30                   Donut Shop                Gas Station
# 31                  Flower Shop              Train Station
# 33            Food & Drink Shop       Fast Food Restaurant
# 34                   Sports Bar             Scenic Lookout
# 35                Train Station         Salon / Barbershop
# 36                   Donut Shop              Train Station
# 37         Fast Food Restaurant             Discount Store
# 39       Furniture / Home Store                Music Venue
# 40                Deli / Bodega              Moving Target
# 43                Shopping Mall                Coffee Shop
# 44               Discount Store                      Diner
# 46                         Café                Pizza Place
# 47                       Bakery             History Museum
# 48                   Restaurant                 Bagel Shop
# 49  Eastern European Restaurant                       Park
# 50               Cosmetics Shop             Sandwich Place
# 51                  Event Space                 Food Truck
# 54           Chinese Restaurant              Deli / Bodega
# 55             Sushi Restaurant                   Pharmacy
# 57                 Liquor Store                     Market
# 58   Construction & Landscaping                 Bagel Shop
# 59                   Bagel Shop         Falafel Restaurant
# 60                       Bakery             Massage Studio
# 61                Smoothie Shop         Mexican Restaurant
#
#                        7th Most Common Venue      8th Most Common Venue  \
# 0                              Deli / Bodega                 Donut Shop
# 2   Residential Building (Apartment / Condo)                 Restaurant
# 3                Eastern European Restaurant                 Donut Shop
# 4                                 Board Shop               Burger Joint
# 7                          French Restaurant                 Food Truck
# 9                          Other Repair Shop       Fast Food Restaurant
# 11                                 Mini Golf             Sandwich Place
# 12                                 Bookstore                Coffee Shop
# 13                                       Gym             Baseball Field
# 14                              Dessert Shop              Deli / Bodega
# 16                            Sandwich Place         Falafel Restaurant
# 17                                Donut Shop             Sandwich Place
# 18                                Restaurant              Train Station
# 19                            Cosmetics Shop                Coffee Shop
# 20                             Deli / Bodega         Athletics & Sports
# 21                        Mexican Restaurant                Supermarket
# 25                                Food Truck          Food & Drink Shop
# 26                         Food & Drink Shop                       Food
# 28                 Middle Eastern Restaurant   Mediterranean Restaurant
# 30                             Grocery Store              Jewelry Store
# 31                      Fast Food Restaurant                   Pharmacy
# 33                        Mexican Restaurant                Event Space
# 34                                     Beach                 Restaurant
# 35                          Sushi Restaurant               Liquor Store
# 36                                      Bank              Deli / Bodega
# 37                              Dessert Shop        Rental Car Location
# 39                                Donut Shop                Pizza Place
# 40                               Dry Cleaner          Convenience Store
# 43                   Health & Beauty Service                        Gym
# 44                         French Restaurant                 Food Truck
# 46                               Supermarket         Chinese Restaurant
# 47                               Dry Cleaner        Filipino Restaurant
# 48                            Baseball Field         Chinese Restaurant
# 49                        Chinese Restaurant  Cajun / Creole Restaurant
# 50                                      Park                Coffee Shop
# 51                         Food & Drink Shop                       Food
# 54                            Ice Cream Shop        American Restaurant
# 55                               Pizza Place                    Dog Run
# 57                    Furniture / Home Store          French Restaurant
# 58                                      Park                 Food Truck
# 59                                Food Truck          Food & Drink Shop
# 60                        Falafel Restaurant                 Food Truck
# 61                            Sandwich Place                       Bank
#
#    9th Most Common Venue  ...  11th Most Common Venue  \
# 0          Hot Dog Joint  ...             Pizza Place
# 2             Donut Shop  ...              Skate Park
# 3         Sandwich Place  ...          Breakfast Spot
# 4                   Café  ...       German Restaurant
# 7      Food & Drink Shop  ...             Flower Shop
# 9      Food & Drink Shop  ...             Flower Shop
# 11          Burger Joint  ...          Ice Cream Shop
# 12    Mexican Restaurant  ...           Grocery Store
# 13           Sports Club  ...              Donut Shop
# 14    Salon / Barbershop  ...             Coffee Shop
# 16    Chinese Restaurant  ...      Spanish Restaurant
# 17           Coffee Shop  ...               Gastropub
# 18      Sushi Restaurant  ...                  Bakery
# 19    Chinese Restaurant  ...      Mexican Restaurant
# 20   Filipino Restaurant  ...  Furniture / Home Store
# 21        Sandwich Place  ...               Rock Club
# 25                  Food  ...     Filipino Restaurant
# 26           Flower Shop  ...    Fast Food Restaurant
# 28           Supermarket  ...          Sandwich Place
# 30          Liquor Store  ...            Optical Shop
# 31            Bagel Shop  ...       Convenience Store
# 33         Tanning Salon  ...                     Bar
# 34          Skating Rink  ...      Falafel Restaurant
# 35        Shipping Store  ...             Flower Shop
# 36        Ice Cream Shop  ...      Falafel Restaurant
# 37        Cosmetics Shop  ...          Ice Cream Shop
# 39      Department Store  ...              Shoe Store
# 40          Liquor Store  ...           Grocery Store
# 43            Donut Shop  ...              Restaurant
# 44     Food & Drink Shop  ...             Flower Shop
# 46      Sushi Restaurant  ...           Tattoo Parlor
# 47            Food Truck  ...          Discount Store
# 48          Concert Hall  ...               Gastropub
# 49              Bus Stop  ...                  Museum
# 50           Flower Shop  ...    Fast Food Restaurant
# 51           Flower Shop  ...    Fast Food Restaurant
# 54      Toy / Game Store  ...                    Food
# 55    Chinese Restaurant  ...              Bagel Shop
# 57            Food Truck  ...                    Food
# 58     Food & Drink Shop  ...             Flower Shop
# 59                  Food  ...     Filipino Restaurant
# 60     Food & Drink Shop  ...             Flower Shop
# 61               Dog Run  ...             Dry Cleaner
#
#          12th Most Common Venue       13th Most Common Venue  \
# 0                         Plaza                   Steakhouse
# 2          Fast Food Restaurant           Spanish Restaurant
# 3                    Restaurant               Cosmetics Shop
# 4                Ice Cream Shop                    Juice Bar
# 7           Filipino Restaurant                  Event Space
# 9           Filipino Restaurant                  Event Space
# 11                   Bagel Shop                       Bakery
# 12                   Soup Place                   Donut Shop
# 13            Electronics Store                  Event Space
# 14             Sushi Restaurant            Indian Restaurant
# 16                Grocery Store                 Dessert Shop
# 17                 Gourmet Shop                          Gym
# 18         Fast Food Restaurant                         Food
# 19             Sushi Restaurant                Grocery Store
# 20            French Restaurant                   Food Truck
# 21                         Café                          Pub
# 25         Fast Food Restaurant            Electronics Store
# 26                  Event Space                  Gas Station
# 28                   Food Truck                     Pharmacy
# 30                     Pharmacy                  Pizza Place
# 31           Chinese Restaurant                Tattoo Parlor
# 33  Eastern European Restaurant                     Bus Stop
# 34                 Dessert Shop                  Flower Shop
# 35          Filipino Restaurant         Fast Food Restaurant
# 36            Food & Drink Shop                         Food
# 37                   Toll Plaza                Train Station
# 39                 Burger Joint                  Supermarket
# 40            Food & Drink Shop                         Food
# 43                  Dry Cleaner  Eastern European Restaurant
# 44          Filipino Restaurant         Fast Food Restaurant
# 46              Thai Restaurant           Tex-Mex Restaurant
# 47            Food & Drink Shop                         Food
# 48                 Intersection                  Music Store
# 49             Storage Facility           Mexican Restaurant
# 50           Falafel Restaurant                  Event Space
# 51           Falafel Restaurant  Eastern European Restaurant
# 54                  Flower Shop          Filipino Restaurant
# 55                    BBQ Joint          Filipino Restaurant
# 57                  Flower Shop          Filipino Restaurant
# 58          Filipino Restaurant         Fast Food Restaurant
# 59         Fast Food Restaurant            Electronics Store
# 60          Filipino Restaurant         Fast Food Restaurant
# 61  Eastern European Restaurant            French Restaurant
#
#          14th Most Common Venue       15th Most Common Venue  \
# 0           American Restaurant             Toy / Game Store
# 2                   Pizza Place             Asian Restaurant
# 3                Ice Cream Shop                  Video Store
# 4            Mexican Restaurant          American Restaurant
# 7            Falafel Restaurant                  Gas Station
# 9            Falafel Restaurant            French Restaurant
# 11          Filipino Restaurant                  Gas Station
# 12                   Restaurant                     Pharmacy
# 13  Eastern European Restaurant                  Dry Cleaner
# 14                   Bagel Shop        Vietnamese Restaurant
# 16                Train Station                   Bagel Shop
# 17                        Diner                Train Station
# 18          Filipino Restaurant                  Flower Shop
# 19                   Donut Shop                   Bagel Shop
# 20            Food & Drink Shop                         Food
# 21                         Pool               Ice Cream Shop
# 25                  Event Space       Furniture / Home Store
# 26            Electronics Store  Eastern European Restaurant
# 28                   Bagel Shop           Athletics & Sports
# 30                   Playground                   Restaurant
# 31             Basketball Court               Sandwich Place
# 33                  Wings Joint                 Dessert Shop
# 34          Filipino Restaurant         Fast Food Restaurant
# 35           Falafel Restaurant                  Event Space
# 36                  Flower Shop          Filipino Restaurant
# 37                   Bagel Shop                       Arcade
# 39              Supplement Shop          American Restaurant
# 40                  Flower Shop          Filipino Restaurant
# 43                   Food Truck                      Dog Run
# 44           Falafel Restaurant           Dim Sum Restaurant
# 46                        Diner          Japanese Restaurant
# 47                  Flower Shop         Fast Food Restaurant
# 48                  Pizza Place                  Yoga Studio
# 49               Discount Store                       Bakery
# 50                  Yoga Studio            Electronics Store
# 51            Electronics Store       Furniture / Home Store
# 54         Fast Food Restaurant           Falafel Restaurant
# 55                  Gas Station       Furniture / Home Store
# 57                  Event Space           Falafel Restaurant
# 58                  Event Space           Falafel Restaurant
# 59                  Event Space       Furniture / Home Store
# 60                  Event Space       Furniture / Home Store
# 61            Electronics Store                  Event Space
#
#          16th Most Common Venue       17th Most Common Venue  \
# 0                       Theater           Tex-Mex Restaurant
# 2                          Bank                          Bar
# 3                Discount Store          Filipino Restaurant
# 4                   Wings Joint                   Donut Shop
# 7             Electronics Store  Eastern European Restaurant
# 9             Electronics Store  Eastern European Restaurant
# 11       Furniture / Home Store            French Restaurant
# 12                Deli / Bodega                  Pizza Place
# 13                      Dog Run           Falafel Restaurant
# 14                       Bakery                          Bar
# 16          Japanese Restaurant      Health & Beauty Service
# 17                       Bakery                 Liquor Store
# 18                  Event Space           Falafel Restaurant
# 19                         Bank                 Liquor Store
# 20                  Flower Shop         Fast Food Restaurant
# 21       Thrift / Vintage Store                    BBQ Joint
# 25  Eastern European Restaurant                  Dry Cleaner
# 26                  Dry Cleaner                   Donut Shop
# 28                   Donut Shop            Food & Drink Shop
# 30          American Restaurant                  Video Store
# 31             Sushi Restaurant            Electronics Store
# 33                    BBQ Joint                     Pharmacy
# 34                  Event Space            Electronics Store
# 35                  Yoga Studio  Eastern European Restaurant
# 36         Fast Food Restaurant            Electronics Store
# 37            French Restaurant                   Food Truck
# 39          Arts & Crafts Store                       Bakery
# 40         Fast Food Restaurant            Electronics Store
# 43               Discount Store                  Event Space
# 44       Furniture / Home Store            Electronics Store
# 46            Convenience Store               Ice Cream Shop
# 47  Eastern European Restaurant           Falafel Restaurant
# 48                Tattoo Parlor                   Donut Shop
# 49                 Intersection                   Hookah Bar
# 50            Food & Drink Shop  Eastern European Restaurant
# 51                  Dry Cleaner                   Donut Shop
# 54                  Event Space            Electronics Store
# 55            French Restaurant                   Food Truck
# 57                    Gastropub            Electronics Store
# 58       Furniture / Home Store            Electronics Store
# 59  Eastern European Restaurant                  Dry Cleaner
# 60            Electronics Store  Eastern European Restaurant
# 61           Falafel Restaurant               Discount Store
#
#          18th Most Common Venue  19th Most Common Venue  \
# 0                       Dog Run    Fast Food Restaurant
# 2                  Gourmet Shop          Hardware Store
# 3          Fast Food Restaurant             Flower Shop
# 4           Filipino Restaurant    Fast Food Restaurant
# 7                   Dry Cleaner              Donut Shop
# 9                   Dry Cleaner              Donut Shop
# 11                   Food Truck       Food & Drink Shop
# 12                   Hookah Bar             Flower Shop
# 13         Fast Food Restaurant     Filipino Restaurant
# 14                  Flower Shop  Furniture / Home Store
# 16                  Dry Cleaner              Hobby Shop
# 17  Eastern European Restaurant      Falafel Restaurant
# 18                  Yoga Studio       Electronics Store
# 19                       Bakery               Juice Bar
# 20                        Diner      Falafel Restaurant
# 21                       Bakery                    Park
# 25                   Donut Shop                 Dog Run
# 26                      Dog Run          Discount Store
# 28                         Food                  Arcade
# 30             Tapas Restaurant             Flower Shop
# 31          Filipino Restaurant      Falafel Restaurant
# 33             Asian Restaurant       Convenience Store
# 34            Food & Drink Shop             Dry Cleaner
# 35                  Dry Cleaner       Food & Drink Shop
# 36                  Event Space                 Dog Run
# 37            Food & Drink Shop                    Food
# 39             Video Game Store               Gastropub
# 40           Falafel Restaurant             Event Space
# 43           Falafel Restaurant    Fast Food Restaurant
# 44  Eastern European Restaurant             Dry Cleaner
# 46                  Wings Joint                 Dog Run
# 47                  Event Space  Furniture / Home Store
# 48          Filipino Restaurant    Fast Food Restaurant
# 49                 Home Service             Flower Shop
# 50                  Dry Cleaner              Donut Shop
# 51                      Dog Run          Discount Store
# 54                  Dry Cleaner              Food Truck
# 55            Food & Drink Shop                    Food
# 57  Eastern European Restaurant             Dry Cleaner
# 58  Eastern European Restaurant             Dry Cleaner
# 59                   Donut Shop                 Dog Run
# 60                  Dry Cleaner              Donut Shop
# 61                        Diner      Dim Sum Restaurant
#
#          20th Most Common Venue
# 0            Falafel Restaurant
# 2             Electronics Store
# 3                   Dry Cleaner
# 4            Falafel Restaurant
# 7                       Dog Run
# 9                       Dog Run
# 11                         Food
# 12                      Dog Run
# 13                  Flower Shop
# 14            French Restaurant
# 16                  Event Space
# 17                   Hobby Shop
# 18  Eastern European Restaurant
# 19                   Hobby Shop
# 20                  Event Space
# 21         Fast Food Restaurant
# 25               Discount Store
# 26                        Diner
# 28                  Flower Shop
# 30         Fast Food Restaurant
# 31                  Event Space
# 33                  Pizza Place
# 34                   Donut Shop
# 35                      Dog Run
# 36  Eastern European Restaurant
# 37                  Flower Shop
# 39                   Art Museum
# 40            French Restaurant
# 43          Filipino Restaurant
# 44                   Donut Shop
# 46                  Flower Shop
# 47                      Dog Run
# 48           Falafel Restaurant
# 49          Filipino Restaurant
# 50                      Dog Run
# 51                        Diner
# 54                   Donut Shop
# 55                  Flower Shop
# 57                   Donut Shop
# 58                   Donut Shop
# 59               Discount Store
# 60                      Dog Run
# 61          Filipino Restaurant
#
# [43 rows x 21 columns]

# %%
#Examination of CLusters #2
si_merged.loc[si_merged['Cluster Labels'] == 1, si_merged.columns[[1] + list(range(5, si_merged.shape[1]))]]
# Out:
#      Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 1    New Brighton              Bus Stop                  Park
# 8   Port Richmond         Deli / Bodega              Bus Stop
# 15        Oakwood         Women's Store                   Bar
# 24      Park Hill              Bus Stop                 Hotel
# 27      Arlington              Bus Stop   American Restaurant
# 29       Grasmere              Bus Stop         Grocery Store
# 32  Midland Beach              Bus Stop                 Beach
# 38   Butler Manor                  Pool        Baseball Field
# 41  Arden Heights           Coffee Shop              Bus Stop
# 42     Greenridge                 Diner                   Pub
# 45     Bloomfield            Theme Park        Discount Store
# 52  Randall Manor                  Park         Deli / Bodega
# 56    Willowbrook              Bus Stop            Bagel Shop
# 62      Fox Hills         Deli / Bodega                   Bar
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1          Deli / Bodega         Bowling Alley        Discount Store
# 8    Rental Car Location            Donut Shop           Pizza Place
# 15              Bus Stop            Playground     French Restaurant
# 24    Athletics & Sports  Gym / Fitness Center           Coffee Shop
# 27         Boat or Ferry         Grocery Store           Coffee Shop
# 29    Italian Restaurant                  Bank   Japanese Restaurant
# 32         Deli / Bodega      Basketball Court            Restaurant
# 38     Convenience Store              Bus Stop           Yoga Studio
# 41           Pizza Place                Lawyer              Pharmacy
# 42            Playground           Pizza Place              Bus Stop
# 45              Bus Stop                  Park     Recreation Center
# 52              Bus Stop            Playground           Pizza Place
# 56    Chinese Restaurant           Yoga Studio  Fast Food Restaurant
# 62              Bus Stop        Sandwich Place            Playground
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1      Convenience Store            Playground            Food Truck
# 8     Mexican Restaurant    Falafel Restaurant     Food & Drink Shop
# 15            Food Truck     Food & Drink Shop                  Food
# 24           Yoga Studio    Falafel Restaurant            Food Truck
# 27  Fast Food Restaurant            Food Truck     Food & Drink Shop
# 29            Nail Salon                  Park              Pharmacy
# 32             Pet Store                  Café             Bookstore
# 38  Fast Food Restaurant     French Restaurant            Food Truck
# 41    Falafel Restaurant            Food Truck     Food & Drink Shop
# 42         Bowling Alley  Fast Food Restaurant            Food Truck
# 45               Dog Run  Fast Food Restaurant            Food Truck
# 52            Bagel Shop           Yoga Studio     Food & Drink Shop
# 56     French Restaurant            Food Truck     Food & Drink Shop
# 62                  Food            Food Truck     Food & Drink Shop
#
#    9th Most Common Venue  ...   11th Most Common Venue 12th Most Common Venue  \
# 1      Food & Drink Shop  ...              Flower Shop    Filipino Restaurant
# 8                   Food  ...      Filipino Restaurant   Fast Food Restaurant
# 15           Flower Shop  ...     Fast Food Restaurant     Falafel Restaurant
# 24     Food & Drink Shop  ...              Flower Shop    Filipino Restaurant
# 27                  Food  ...      Filipino Restaurant     Falafel Restaurant
# 29        Ice Cream Shop  ...           Cosmetics Shop          Deli / Bodega
# 32          Dessert Shop  ...  Health & Beauty Service      Food & Drink Shop
# 38     Food & Drink Shop  ...              Flower Shop    Filipino Restaurant
# 41                  Food  ...      Filipino Restaurant   Fast Food Restaurant
# 42     Food & Drink Shop  ...              Flower Shop    Filipino Restaurant
# 45     Food & Drink Shop  ...       Dim Sum Restaurant            Flower Shop
# 52                  Food  ...      Filipino Restaurant   Fast Food Restaurant
# 56                  Food  ...      Filipino Restaurant     Falafel Restaurant
# 62           Flower Shop  ...     Fast Food Restaurant     Falafel Restaurant
#
#     13th Most Common Venue         14th Most Common Venue  \
# 1     Fast Food Restaurant                    Event Space
# 8        Electronics Store                    Event Space
# 15             Gas Station                    Event Space
# 24    Fast Food Restaurant                    Event Space
# 27  Furniture / Home Store                    Event Space
# 29                  Bakery  Vegetarian / Vegan Restaurant
# 32                    Food                    Flower Shop
# 38      Falafel Restaurant                    Gas Station
# 41             Yoga Studio                    Event Space
# 42       Electronics Store             Falafel Restaurant
# 45     Filipino Restaurant             Falafel Restaurant
# 52      Falafel Restaurant              Electronics Store
# 56             Gas Station                    Event Space
# 62             Event Space         Furniture / Home Store
#
#     15th Most Common Venue       16th Most Common Venue  \
# 1       Falafel Restaurant           Dim Sum Restaurant
# 8        French Restaurant  Eastern European Restaurant
# 15       Electronics Store  Eastern European Restaurant
# 24  Furniture / Home Store            Electronics Store
# 27       Electronics Store  Eastern European Restaurant
# 29              Bagel Shop                  Flower Shop
# 32     Filipino Restaurant         Fast Food Restaurant
# 38             Event Space            Electronics Store
# 41  Furniture / Home Store            Electronics Store
# 42             Event Space  Eastern European Restaurant
# 45              Donut Shop                        Diner
# 52             Event Space            French Restaurant
# 56       Electronics Store  Eastern European Restaurant
# 62       Electronics Store  Eastern European Restaurant
#
#          17th Most Common Venue       18th Most Common Venue  \
# 1             Electronics Store  Eastern European Restaurant
# 8                   Dry Cleaner                      Dog Run
# 15                  Dry Cleaner                   Donut Shop
# 24  Eastern European Restaurant                  Dry Cleaner
# 27                  Dry Cleaner                   Donut Shop
# 29       Furniture / Home Store            French Restaurant
# 32           Falafel Restaurant                  Event Space
# 38  Eastern European Restaurant                  Dry Cleaner
# 41  Eastern European Restaurant                  Dry Cleaner
# 42                  Dry Cleaner                   Donut Shop
# 45            French Restaurant                  Event Space
# 52  Eastern European Restaurant                  Dry Cleaner
# 56                  Dry Cleaner                   Donut Shop
# 62                  Dry Cleaner                   Donut Shop
#
#    19th Most Common Venue       20th Most Common Venue
# 1             Dry Cleaner                   Donut Shop
# 8          Discount Store                        Diner
# 15                Dog Run               Discount Store
# 24             Donut Shop                      Dog Run
# 27                Dog Run               Discount Store
# 29             Food Truck            Food & Drink Shop
# 32                  Hotel            Electronics Store
# 38             Donut Shop                      Dog Run
# 41             Donut Shop                      Dog Run
# 42                Dog Run               Discount Store
# 45      Electronics Store  Eastern European Restaurant
# 52             Donut Shop                      Dog Run
# 56                Dog Run               Discount Store
# 62                Dog Run               Discount Store
#
# [14 rows x 21 columns]

# %%
#Examination of CLusters #3
si_merged.loc[si_merged['Cluster Labels'] == 2, si_merged.columns[[1] + list(range(5, si_merged.shape[1]))]]
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 6    Todt Hill                  Park           Yoga Studio
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 6    Falafel Restaurant     French Restaurant            Food Truck
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 6     Food & Drink Shop                  Food           Flower Shop
#
#   9th Most Common Venue  ... 11th Most Common Venue 12th Most Common Venue  \
# 6   Filipino Restaurant  ...            Event Space           Intersection
#
#   13th Most Common Venue       14th Most Common Venue 15th Most Common Venue  \
# 6      Electronics Store  Eastern European Restaurant            Dry Cleaner
#
#   16th Most Common Venue 17th Most Common Venue 18th Most Common Venue  \
# 6             Donut Shop                Dog Run         Discount Store
#
#   19th Most Common Venue 20th Most Common Venue
# 6                  Diner     Dim Sum Restaurant
#
# [1 rows x 21 columns]

# %%
#Examination of CLusters #4
si_merged.loc[si_merged['Cluster Labels'] == 3, si_merged.columns[[1] + list(range(5, si_merged.shape[1]))]]
# Out:
#    Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 5   Grymes Hill         Moving Target               Dog Run
# 22  Silver Lake   American Restaurant          Burger Joint
# 23    Sunnyside   American Restaurant               Theater
#
#    3rd Most Common Venue 4th Most Common Venue   5th Most Common Venue  \
# 5                    Gym           Yoga Studio    Fast Food Restaurant
# 22           Golf Course                   Gym  Furniture / Home Store
# 23                   Spa         Grocery Store                     Gym
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 5      French Restaurant            Food Truck     Food & Drink Shop
# 22            Food Truck     Food & Drink Shop                  Food
# 23                Market     Food & Drink Shop                  Food
#
#    9th Most Common Venue  ... 11th Most Common Venue 12th Most Common Venue  \
# 5                   Food  ...    Filipino Restaurant     Falafel Restaurant
# 22           Flower Shop  ...   Fast Food Restaurant     Falafel Restaurant
# 23           Flower Shop  ...   Fast Food Restaurant     Falafel Restaurant
#
#    13th Most Common Venue 14th Most Common Venue       15th Most Common Venue  \
# 5             Gas Station            Event Space            Electronics Store
# 22            Event Space      Electronics Store  Eastern European Restaurant
# 23            Event Space      French Restaurant            Electronics Store
#
#          16th Most Common Venue 17th Most Common Venue 18th Most Common Venue  \
# 5   Eastern European Restaurant            Dry Cleaner             Donut Shop
# 22                  Dry Cleaner             Donut Shop                Dog Run
# 23  Eastern European Restaurant            Dry Cleaner             Donut Shop
#
#    19th Most Common Venue 20th Most Common Venue
# 5          Discount Store                  Diner
# 22         Discount Store                  Diner
# 23                Dog Run         Discount Store
#
# [3 rows x 21 columns]

# %% [markdown]
# # After reviewiwng map and data for Staten Island, I would suggest to explore cluster 2 due to high volume of food/breakfast/deli locations. Coffee shops in Staten Island are not as popular as they are in Toronto, therefore I would suggest to possibly avoid Staten Island all-together. In addition, due to popularity of local delis and donut/bagel shops, the market seems to be oversaturated with baked good that are produced fresh at the location of the business, therefore I would forecast low demand of baked goods produced by our bakery.

# %% [markdown]
# # Conclusion: Avoid Staten Island as a possible exapnsion area for out bakery, and concentrate on expanding in downtown Toronto area.
